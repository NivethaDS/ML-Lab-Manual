# %% [markdown]
# ### Lab4:House Price Prediction using Linear Regression with Regularization

# %% [markdown]
# Name:K.Nivetha
# Roll No:235229120

# %% [markdown]
# #### Step1.Import dataset

# %%
import pandas as pd

# %%
data=pd.read_csv("Ames_House_Sales_Cropped.csv")
data
# Out:
#      BldgType CentralAir  1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# 0        1Fam          Y       856       854          0             3
# 1        1Fam          Y      1262         0          0             3
# 2        1Fam          Y       920       866          0             3
# 3        1Fam          Y       961       756          0             3
# 4        1Fam          Y      1145      1053          0             4
# ...       ...        ...       ...       ...        ...           ...
# 1374     1Fam          Y       953       694          0             3
# 1375     1Fam          Y      2073         0          0             3
# 1376     1Fam          Y      1188      1152          0             4
# 1377     1Fam          Y      1078         0          0             2
# 1378     1Fam          Y      1256         0          0             3
#
#       BsmtFinSF1  BsmtFinSF2  BsmtFullBath  BsmtHalfBath  ...  OverallQual  \
# ...

# %%
#head
data.head()
# Out:
#   BldgType CentralAir  1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  \
# 0     1Fam          Y       856       854          0             3
# 1     1Fam          Y      1262         0          0             3
# 2     1Fam          Y       920       866          0             3
# 3     1Fam          Y       961       756          0             3
# 4     1Fam          Y      1145      1053          0             4
#
#    BsmtFinSF1  BsmtFinSF2  BsmtFullBath  BsmtHalfBath  ...  OverallQual  \
# 0         706           0             1             0  ...            7
# 1         978           0             0             1  ...            6
# 2         486           0             1             0  ...            7
# 3         216           0             1             0  ...            7
# 4         655           0             1             0  ...            8
#
#    PoolArea  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  YearBuilt  \
# ...

# %%
#shape
data.shape
# Out:
# (1379, 39)

# %%
#columns
data.shape[1]
# Out:
# 39

# %%
#dtype
data.dtypes
# Out:
# BldgType          object
# CentralAir        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# 3SsnPorch          int64
# BedroomAbvGr       int64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# BsmtUnfSF          int64
# EnclosedPorch      int64
# Fireplaces         int64
# FullBath           int64
# GarageArea         int64
# GarageCars         int64
# GarageYrBlt        int64
# GrLivArea          int64
# HalfBath           int64
# KitchenAbvGr       int64
# LotArea            int64
# LotFrontage      float64
# LowQualFinSF       int64
# MSSubClass         int64
# MasVnrArea         int64
# MiscVal            int64
# MoSold             int64
# OpenPorchSF        int64
# OverallCond        int64
# OverallQual        int64
# PoolArea           int64
# ScreenPorch        int64
# TotRmsAbvGrd       int64
# TotalBsmtSF        int64
# WoodDeckSF         int64
# YearBuilt          int64
# YearRemodAdd       int64
# ...

# %%
#info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1379 entries, 0 to 1378
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BldgType       1379 non-null   object
#  1   CentralAir     1379 non-null   object
#  2   1stFlrSF       1379 non-null   int64
#  3   2ndFlrSF       1379 non-null   int64
#  4   3SsnPorch      1379 non-null   int64
#  5   BedroomAbvGr   1379 non-null   int64
#  6   BsmtFinSF1     1379 non-null   int64
#  7   BsmtFinSF2     1379 non-null   int64
#  8   BsmtFullBath   1379 non-null   int64
#  9   BsmtHalfBath   1379 non-null   int64
#  10  BsmtUnfSF      1379 non-null   int64
#  11  EnclosedPorch  1379 non-null   int64
#  12  Fireplaces     1379 non-null   int64
#  13  FullBath       1379 non-null   int64
#  14  GarageArea     1379 non-null   int64
#  15  GarageCars     1379 non-null   int64
#  16  GarageYrBlt    1379 non-null   int64
#  17  GrLivArea      1379 non-null   int64
# ...

# %%
#value_counts
data.CentralAir.value_counts()
# Out:
# Y    1310
# N      69
# Name: CentralAir, dtype: int64

# %% [markdown]
# #### Step2.Predict Sale Price without Categorical features

# %%
df=data.drop("BldgType",axis=1)
print(df)
# Out:
#      CentralAir  1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  \
# 0             Y       856       854          0             3         706
# 1             Y      1262         0          0             3         978
# 2             Y       920       866          0             3         486
# 3             Y       961       756          0             3         216
# 4             Y      1145      1053          0             4         655
# ...         ...       ...       ...        ...           ...         ...
# 1374          Y       953       694          0             3           0
# 1375          Y      2073         0          0             3         790
# 1376          Y      1188      1152          0             4         275
# 1377          Y      1078         0          0             2          49
# 1378          Y      1256         0          0             3         830
#
#       BsmtFinSF2  BsmtFullBath  BsmtHalfBath  BsmtUnfSF  ...  OverallQual  \
# ...

# %%
df.drop("CentralAir",axis=1)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3         706           0
# 1         1262         0          0             3         978           0
# 2          920       866          0             3         486           0
# 3          961       756          0             3         216           0
# 4         1145      1053          0             4         655           0
# ...        ...       ...        ...           ...         ...         ...
# 1374       953       694          0             3           0           0
# 1375      2073         0          0             3         790         163
# 1376      1188      1152          0             4         275           0
# 1377      1078         0          0             2          49        1029
# 1378      1256         0          0             3         830         290
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# ...

# %%
df3=data.pop("BldgType")
print(df3)
# Out:
# 0       1Fam
# 1       1Fam
# 2       1Fam
# 3       1Fam
# 4       1Fam
#         ...
# 1374    1Fam
# 1375    1Fam
# 1376    1Fam
# 1377    1Fam
# 1378    1Fam
# Name: BldgType, Length: 1379, dtype: object

# %%
df=data.pop("CentralAir")
df
# Out:
# 0       Y
# 1       Y
# 2       Y
# 3       Y
# 4       Y
#        ..
# 1374    Y
# 1375    Y
# 1376    Y
# 1377    Y
# 1378    Y
# Name: CentralAir, Length: 1379, dtype: object

# %%
data
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0          856       854          0             3         706           0
# 1         1262         0          0             3         978           0
# 2          920       866          0             3         486           0
# 3          961       756          0             3         216           0
# 4         1145      1053          0             4         655           0
# ...        ...       ...        ...           ...         ...         ...
# 1374       953       694          0             3           0           0
# 1375      2073         0          0             3         790         163
# 1376      1188      1152          0             4         275           0
# 1377      1078         0          0             2          49        1029
# 1378      1256         0          0             3         830         290
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallQual  \
# ...

# %%
y=data[["SalePrice"]]
y
# Out:
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1374     175000
# 1375     210000
# 1376     266500
# 1377     142125
# 1378     147500
#
# [1379 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['BldgType', 'CentralAir', 'SalePrice'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 X = df.drop(['BldgType', 'CentralAir', 'SalePrice'], axis=1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
#
# NameError: name 'X' is not defined

# %%
type(df)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Step3.Create Scatter Plot

# %%
import matplotlib.pyplot as plt
